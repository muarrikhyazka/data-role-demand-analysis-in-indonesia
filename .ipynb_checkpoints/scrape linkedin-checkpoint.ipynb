# %%
##import libraries
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

##Need adjustment on xpath

# %% [markdown]
# # Defining job and country/location

# %%
job_name = "Data"
country_name = "Indonesia"

#We create the corresponding job name in URL
job_url ="";
for item in job_name.split(" "):
    if item != job_name.split(" ")[-1]:
        job_url = job_url + item + "%20"
    else:
        job_url = job_url + item
        
#We create the  corresponding country name in URL
country_url ="";
for item in country_name.split(" "):
    if item != country_name.split(" ")[-1]:
        country_url = country_url + item + "%20"
    else:
        country_url = country_url + item

url = "https://www.linkedin.com/jobs/search?keywords={0}&location={1}&geoId=102478259&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0".format(job_url,country_url)
url
# Out:
# 'https://www.linkedin.com/jobs/search?keywords=Data&location=Indonesia&geoId=102478259&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0'

# %% [markdown]
# # Loading Driver

# %%
# Creating a webdriver instance
driver = webdriver.Chrome("./chromedriver")
# Opening the url we have just defined in our browser
driver.get(url)

# %% [markdown]
# # Detecting elements in our Browser

# %%
#We find how many jobs are offered.
jobs_num = driver.find_element(By.CSS_SELECTOR,"h1>span").get_attribute("innerText")
if len(jobs_num.split(',')) > 1:
    jobs_num = int(jobs_num.split(',')[0])*1000
else:
    jobs_num = int(jobs_num)

jobs_num   = int(jobs_num)

#Here I choose manually a number of jobs, so it wont take that long:
jobs_num = 1000;


#We create a while loop to browse all jobs. 
i = 2
while i <= int(jobs_num/2)+1:
    #We keep scrollind down to the end of the view.
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    i = i + 1
    print("Current at: ", i, "Percentage at: ", ((i+1)/(int(jobs_num/2)+1))*100, "%",end="\r")
    try:
        #We try to click on the load more results buttons in case it is already displayed.
        infinite_scroller_button = driver.find_element(By.XPATH, ".//button[@aria-label='Load more results']")
        infinite_scroller_button.click()
        time.sleep(0.1)
    except:
        #If there is no button, there will be an error, so we keep scrolling down.
        time.sleep(0.1)
        pass
# Out:
# Current at:  502 Percentage at:  100.39920159680639 %

# %% [markdown]
# # Loading Basic Data

# %%
#We get a list containing all jobs that we have found.
job_lists = driver.find_element(By.CLASS_NAME,"jobs-search__results-list")
jobs = job_lists.find_elements(By.TAG_NAME,"li") # return a list

#We declare void list to keep track of all obtaind data.
job_title_list = []
company_name_list = []
location_list = []
date_list = []
job_link_list = []

#We loof over every job and obtain all the wanted info.
for job in jobs:
    #job_title
    job_title = job.find_element(By.CSS_SELECTOR,"h3").get_attribute("innerText")
    job_title_list.append(job_title)
    
    #company_name
    company_name = job.find_element(By.CSS_SELECTOR,"h4").get_attribute("innerText")
    company_name_list.append(company_name)
    
    #location
    location = job.find_element(By.CSS_SELECTOR,"div>div>span").get_attribute("innerText")
    location_list.append(location)
    
    #date
    date = job.find_element(By.CSS_SELECTOR,"div>div>time").get_attribute("datetime")
    date_list.append(date)
    
    #job_link
    job_link = job.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
    job_link_list.append(job_link)

# %% [markdown]
# # Loading More Data

# %%
# url = 'https://id.linkedin.com/jobs/view/it-business-information-at-asuransi-astra-3550596130?refId=31IhIA%2BzO8ilEeyAdxc6Kg%3D%3D&trackingId=%2BuWxA02Tm0wDMXxi4BKc2Q%3D%3D&position=25&pageNum=6&trk=public_jobs_jserp-result_search-card'

# %%
# # Creating a webdriver instance
# driver = webdriver.Chrome("./chromedriver")
# # Opening the url we have just defined in our browser
# driver.get(url)

# %%
# # Creating a webdriver instance
# driver = webdriver.Chrome("./chromedriver")
# # Opening the url we have just defined in our browser
# driver.get(url)

# jd_path = '//*[@id="main-content"]/section[1]/div/div/section[1]/div/div/section/div'
# jd_path = '/html/body/main/section[1]/div/div/section[1]/div/div/section/div'
# jd = []  

# jd0 = driver.find_element(By.XPATH,jd_path).get_attribute('innerText')

# # jd0 = job.find_element(By.CSS_SELECTOR,"#main-content > section.core-rail.mx-auto.papabear\:w-core-rail-width.mamabear\:max-w-\[790px\].babybear\:max-w-\[790px\] > div > div > section.core-section-container.my-3.description > div > div > section > div").get_attribute("innerText")


# print(jd0)

# %%
# jd = [] #job_description
# seniority = []
# emp_type = []
# job_func = []
# job_ind = []
# for item in range(len(jobs)):
#     job_func0=[]
#     industries0=[]
#     # clicking job to view job details
    
#     #__________________________________________________________________________ JOB Link
    
#     try: 
#         job_click_path = f'/html/body/div/div/main/section/ul/li[{item+1}]'
#         job_click = job.find_element(By.XPATH,job_click_path).click()
#     except:
#         pass
#     #job_click = job.find_element(By.XPATH,'.//a[@class="base-card_full-link"]')
    
#     #__________________________________________________________________________ JOB Description
#     jd_path = '/html/body/main/section[1]/div/div/section[1]/div/div/section/div'
    
#     try:
#         jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
#         jd.append(jd0)
#     except:
#         jd.append(None)
#         pass
    
#     #__________________________________________________________________________ JOB Seniority
#     seniority_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[1]/span'
    
#     try:
#         seniority0 = job.find_element(By.XPATH,seniority_path).get_attribute('innerText')
#         seniority.append(seniority0)
#     except:
#         seniority.append(None)
#         pass

#     #__________________________________________________________________________ JOB Time
#     emp_type_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[2]/span'
    
#     try:
#         emp_type0 = job.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
#         emp_type.append(emp_type0)
#     except:
#         emp_type.append(None)
#         pass
    
#     #__________________________________________________________________________ JOB Function
#     function_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[3]/span'
    
#     try:
#         func0 = job.find_element(By.XPATH,function_path).get_attribute('innerText')
#         job_func.append(func0)
#     except:
#         job_func.append(None)
#         pass

#     #__________________________________________________________________________ JOB Industry
#     industry_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[4]/span'
    
#     try:
#         ind0 = job.find_element(By.XPATH,industry_path).get_attribute('innerText')
#         job_ind.append(ind0)
#     except:
#         job_ind.append(None)
#         pass
    
#     print("Current at: ", item, "Percentage at: ", (item+1)/len(jobs)*100, "%",end="\r")

# %%
## open new page
jd = [] #job_description
seniority = []
emp_type = []
job_func = []
job_ind = []
item=0
for link in job_link_list:
    time.sleep(5)
    item=+1
    # clicking job to view job details
    
    #__________________________________________________________________________ JOB Link
    
#     try: 
#         job_click_path = f'/html/body/div/div/main/section/ul/li[{item+1}]'
#         job_click = job.find_element(By.XPATH,job_click_path).click()
#     except:
#         pass
    #job_click = job.find_element(By.XPATH,'.//a[@class="base-card_full-link"]')
    driver.get(link)
    
    #__________________________________________________________________________ JOB Description
    jd_path = '/html/body/main/section[1]/div/div/section[1]/div/div/section/div'
                
    
    try:
        jd0 = driver.find_element(By.XPATH,jd_path).get_attribute('innerText')
        jd.append(jd0)
    except:
        jd.append(None)
#         pass
#     jd0 = driver.find_element(By.XPATH,jd_path).get_attribute('innerText')
#     jd.append(jd0)
    
    
    #__________________________________________________________________________ JOB Seniority
    seniority_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[1]/span'
                        
    
    try:
        seniority0 = driver.find_element(By.XPATH,seniority_path).get_attribute('innerText')
        seniority.append(seniority0)
    except:
        seniority.append(None)
#         pass
#     seniority0 = driver.find_element(By.XPATH,seniority_path).get_attribute('innerText')
#     seniority.append(seniority0)

    #__________________________________________________________________________ JOB Time
    emp_type_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[2]/span'
    
    try:
        emp_type0 = driver.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
        emp_type.append(emp_type0)
    except:
        emp_type.append(None)
#         pass
#     emp_type0 = driver.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
#     emp_type.append(emp_type0)
    
    #__________________________________________________________________________ JOB Function
    function_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[3]/span'
    
    try:
        func0 = driver.find_element(By.XPATH,function_path).get_attribute('innerText')
        job_func.append(func0)
    except:
        job_func.append(None)
#         pass
#     func0 = driver.find_element(By.XPATH,function_path).get_attribute('innerText')
#     job_func.append(func0)

    #__________________________________________________________________________ JOB Industry
    industry_path='/html/body/main/section[1]/div/div/section[1]/div/ul/li[4]/span'
    
    try:
        ind0 = driver.find_element(By.XPATH,industry_path).get_attribute('innerText')
        job_ind.append(ind0)
    except:
        job_ind.append(None)
#         pass
#     ind0 = driver.find_element(By.XPATH,industry_path).get_attribute('innerText')
#     job_ind.append(ind0)
#     print(ind0)
    
    print("Current at: ", item, "Percentage at: ", (item+1)/len(job_link_list)*100, "%",end="\r")
# Out:
# Current at:  1 Percentage at:  1.342281879194631 %

# %%
# ## open on side page
# jd = [] #job_description
# seniority = []
# emp_type = []
# job_func = []
# job_ind = []
# item=0
# for link in job_link_list:
#     time.sleep(0.1)
#     item=+1
#     job_func0=[]
#     industries0=[]
#     # clicking job to view job details
    
#     #__________________________________________________________________________ JOB Link
    
# #     try: 
# #         job_click_path = f'/html/body/div/div/main/section/ul/li[{item+1}]'
# #         job_click = job.find_element(By.XPATH,job_click_path).click()
# #     except:
# #         pass
#     #job_click = job.find_element(By.XPATH,'.//a[@class="base-card_full-link"]')
#     driver.get(link)
    
#     #__________________________________________________________________________ JOB Description
#     jd_path = '/html/body/div[1]/div/section/div[2]/div/section[1]/div/div/section/div'
    
#     try:
#         jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
#         jd.append(jd0)
#     except:
#         jd.append(None)
#         pass
    
#     #__________________________________________________________________________ JOB Seniority
#     seniority_path='/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[1]/span'
    
#     try:
#         seniority0 = job.find_element(By.XPATH,seniority_path).get_attribute('innerText')
#         seniority.append(seniority0)
#     except:
#         seniority.append(None)
#         pass

#     #__________________________________________________________________________ JOB Time
#     emp_type_path='/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[2]/span'
    
#     try:
#         emp_type0 = job.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
#         emp_type.append(emp_type0)
#     except:
#         emp_type.append(None)
#         pass
    
#     #__________________________________________________________________________ JOB Function
#     function_path='/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[3]/span'
    
#     try:
#         func0 = job.find_element(By.XPATH,function_path).get_attribute('innerText')
#         job_func.append(func0)
#     except:
#         job_func.append(None)
#         pass

#     #__________________________________________________________________________ JOB Industry
#     industry_path='/html/body/div[1]/div/section/div[2]/div/section[1]/div/ul/li[4]/span'
    
#     try:
#         ind0 = job.find_element(By.XPATH,industry_path).get_attribute('innerText')
#         job_ind.append(ind0)
#     except:
#         job_ind.append(None)
#         pass
    
#     print("Current at: ", item, "Percentage at: ", (item+1)/len(job_link_list)*100, "%",end="\r")

# %%
jd
# Out:
# ['Job Responsibilities\nTo analyze the impact of the regulation development in taxation and industry, so the update information can be used to update about provision, and to give input also advice about tax area for Adaro subsidiaries.\nTo analyze Contracts and document transactions so the data can be used to determine the risk of taxation and tax treatment in accordance with the applicable provisions.\nTo conduct a review all fiscal and taxation reports from Adaro subsidiaries, so the report can be used to prepare recommendations.\nTo gather information related to regulations in the areas of taxation and / or relating to the areas of taxation so it can be used to identify tax issues for the company.\nTo collect and prepare material for all project implementation plan in Adaro subsidiaries.\nTo do the documentation and filing tax documents pertaining to the analysis, a review, updates, input, advice, and recommendations of taxation.\nJob Requirements\nMinimum Bachelor Degree majoring Accounting / Taxation from reputable university, with minimum GPA 3.00\nMinimum 3 years experience in the tax area, preferably from public tax firm.\nHaving excellent knowledge about Tax Regulation.\nHaving good knowledge about Tax Policy & Procedures.\nHaving good analytical thinking.\nFluent in English.',
#  'What You’ll Do\n\nAnalyzing Data\nReporting data and performance.\nResearching social media trends.\nObserving user needs & behavior.\nKeeping up to date of current events to better understand user behavior.\n\nYour Criteria Will Be\n\nMinimum Education Senior High School\nProficient in Microsoft Office and data visualization.\nQuickly adapt to the work environment.\nDetail & creative personality.\nSkilled at creating efficient reporting tools\nHave an executive presentation skills.\nAble to work all out to meet target deadline include weekend.\n\nIf you think you’re the one please feel free to apply via the following link : nolimit.id/jobs/junior-data-analyst/',
#  "A part of Bukalapak, iPrice is the place price-conscious shoppers go to find the cheapest online price. We do this by sorting through the catalogues of e-commerce platforms to identify the cheapest trustworthy offers. These we present to our users to help them make a more informed purchase decision. We tailor our service to product categories where consumers can save the most money.\n\n\n\n\nDescription\n\nBusiness Intelligence is central to the growth of our business, as it provides us with the non-financial data granularity required to understand the levers of growth and how to best pull them to increase traffic and revenues. e are looking for a highly analytical, driven, and curious data guru to join us.\n\n\n\n\nWhy join us?\n\nSurround yourself with a dynamic culture and people who are inclusive, fun, courageous, open to feedback and constantly looking for ways to improve themselves:\n\nCollaborate on solving the Biggest Challenges in Ecommerce\nImmerse yourself in a Multicultural Organization at the Center of SEA\nAccelerate your Personal Growth and Career\n\n\n\n\nResponsibilities:\n\nBe the subject matter expert for analyzing core business and product data and providing insights to a variety of stakeholders\nLeverage state-of-the-art Business Intelligence tools to connect datasets, enable predictive modeling and run sophisticated trend analysis\nProduce insightful reports and data visualization on a weekly and monthly cadence to senior management, leads, and investors, influencing key business decisions\nDesign operational data visualization dashboards that support other teams in monitoring their core KPIs\nClosely work with the tech team and together deploy data to the data warehouse and optimize BI processes\nEnhance data quality through review and validation of data, and implementation of appropriate controls and checkpoints\nRegularly refresh our business plans and prepare analysis for investor communication and fundraising\nWork on financial models for potential mergers and acquisitions as we look for in-organic growth opportunities\n\n\n\n\nRequirements:\n\nBachelor's or Master’s degree in Business, Mathematics, or any related field\n1.5 to 4 years experience in an analytical role, ideally in Business Intelligence, Finance, or Management Consulting in a company known for best-in-class products\nStrong working knowledge of Excel and PowerPoint; Pivot tables, vlookups, and sheets with millions of cells don’t scare you\nCuriosity to crunch large datasets with millions of rows and GBs of data and extract insights in meaningful ways\nExperience with BI software, programming, and database management such as Power BI, DAX, SQL, and Microsoft Azure\nExperienced in working with Software Engineers in an agile environment applying SCRUM methodologies\nA positive can-do attitude combined with the ability to work in a super-fast-paced start-up environment\nFluent in English, excellent in verbal and written communication, strong presentation and persuasion skills\n\n\n\n\nBukalapak is an equal-opportunity employer. Our hiring committee considers all applicants based on their merits and qualifications for each position. Bukalapak does not discriminate against applicants on the basis of their race, color, religion, sex, sexual orientation, gender identity, national origin, disability, or any other characteristics protected by applicable law. We embrace diversity and encourage inclusion because we believe that to help create A Fair Economy For All, we need to build a workplace for all #BukalapakForAll",
#  'Company Description: SigmaTech is the enterprise technology partner of choice for software development, delivering a broad range of web, mobile, and desktop controls coupled with a service-oriented approach throughout the entire application life cycle. SigmaTech consists of highly skilled developers specializing in agile development methodology, focusing on Mobile & Web Solution, IT Services and business enterprise, utilizing modern programming languages as our platform. SigmaTech has established itself as the trusted partner for use in mission-critical applications and service clientele from global insurance company, government agencies and large consumer product manufacturer. Job Description:\n\nIdentify technical obstacles early and work closely with team to find creative solutions to build prototypes & develop deployment strategies, procedures.\nProvide preventative maintenance, troubleshooting, and quick resolution of routine problems to ensure Database infrastructure and application stability.\nWrite and analyze queries, object oriented and/or scripting languages.\nTake an active role in Squad.\nAbility to grasp new technologies rapidly as needed to progress varied initiatives - Break down data issues and resolve them.\nMake sure data movement and do documentation.\nImprove skills as a professional and a team',
#  'Requirements\n\nMin SMK Akuntansi/D3/S1 Jurusan Akuntansi\nMin 1-2 tahun pengalaman di bidang Accounting\nMemiliki pengetahuan yang kuat dan up-to-date tentang peraturan perpajakan\nTerbiasa menangani tugas akuntansi sehari-hari termasuk Piutang, Hutang, dan penggajian\nDapat memperbarui dan memelihara basis data akuntansi dengan entri data dan laporan\nTeliti, detail, perhatian terhadap akurasi, proaktif dan jujur\nDiutamakan domisili Bekasi dan Jakarta Timur\nWFO Senin - Jumat\nPlacement: Jakarta Timur\n\nJob Description\n\nMemeriksa perhitungan dan pelaporan pajak\nMembantu memeriksa pembayaran Faktur pajak\nMengerjakan list pembayaran vendor\nBerkoordinasi dengan seluruh team terkait penjualan, pemasukan, retur, endorsement dsb nya\nMerekap seluruh data penjualan daily di semua E-Commerce (Tokopedia, Shopee, Tokotalk)\nDapat menyajikan laporan keuangan bulanan',
#  'Gambaran Pekerjaan\n\nSebagai Data Analyst, Anda bertugas untuk mengumpulkan, mengolah, dan menyajikan informasi terkait data pelanggan sehingga menjadi rekomendasi bagi tim terkait yaitu tim loyalty program business unit untuk mendukung tercapainya loyalty program yang efektif dan efisien.\n\nKualifikasi\n\nMinimal S1 jurusan Manajemen Informatika/Statistik/Marketing.\nPengalaman 1 tahun di bidang yang sama.\n\nSkill yang Dibutuhkan\n\nR Studio\nPython\nGoogle Data Studio\nAWS\nPresentation skill',
#  "Company Description: We believe that the mind is the root of human behavior, and it is mainly influenced by education. Politics with advanced integrity starts with education, so are healthy and sustainable economic development, technology, and impactful innovation. Therefore, if we’re dreaming of establishing further civilization, we should start from an impactful, inclusive, and meaningful education. That’s us, and that's what we're believe. So if you have a strong vision about disrupting Indonesia's Education Landscape with Business and Technology, join us and challenge yourself! Job Description:\n\nConduct research to support business needs\nCrafting question list to collect data from user\nInterpreting business goals in to objective research\nAnalyzing and synthesis data",
#  'About the position:\n\nAs a part of the Data Analyst team, you will collaborate with our Stakeholders to solve the problems with providing data & analytics solutions. You will play an essential role in the success of creating a data culture in the company by ensuring our Stakeholders can produce data-based decisions. If you are detail oriented and love to work with millions of data, this role can give you the chance to fully develop not only in technical aspects, but business & product acumen as well.\n\n\n\n\nResponsibilities:\n\nProvide analysis to measure impact of new feature, business flow, campaign and present the result in visual way to make data storytelling easier\nCreate new & manage automated report/dashboard based on requirement defined by Stakeholders to ensure Stakeholders consume correct and latest data\nCreate new & manage Data Mart to make work easier & faster\nEnsure correctness of data by collaborate with Data Engineer to maintain data quality aspect\nBecome strategic partner with Stakeholders from various background by advising new metrics, data source, visualization and other analytical methods for better data-based decisions\nAware of beside high accuracy, speed delivery of task as important as well\nStay up-to-date with data and analytics trend\n\n\n\n\nRequirements:\n\nHave experience related with Data (Data Analyst, Data Scientist, Business Intelligence, Business Analyst, Product Analyst, etc) at least 1-2 years\nCan create user-friendly and insightful dashboard/report using one of various BI Tools (Eg: Tableau, Power BI, Google Data Studio, etc)\nMastering SQL to collect & manipulating data and have knowledge of Unstructured Data (Eg: JSON)\nHave experience to provide analysis (Descriptive/Diagnostic/Predictive/Prescriptive) with help of analytics tools (Eg: Big Query, Python, R, SPSS, etc)\nHave knowledge of Data Mining concepts (Eg: Statistics, Machine Learning, Forecasting, etc)\nCan explain of own project which he/she worked on using great storytelling skill\nComfortable working with million rows of data\nThinks out of the box to propose and implement an alternative solution if needed\nGood intrapersonal skills to collaborate within/across function\nSelf driven, high curiosity, problem solving mindset, and very detail-oriented\n\n\n\n\nBonus point if:\n\nExperience in using Google BigQuery and Looker',
#  'Melakukan pengumpulan data pendukung (data sampling) terkait object audit masing-masing cabang\nMelakukan preparation perjalanan dinas (pengisian form perjalanan dinas)\nMelakukan Stock Opname BPKB fisik secara sampling sesuai dengan data yang diberikan branch audit head\nMelakukan proses audit asset Cash Opname\nMembuat report hasil audit setiap cabang dan mengirimkannya kepada Branch Audit Head\nMelaporkan hasil temuan audit kepada Branch Audit Head\nMelakukan realisasi SPD\n\nMinimum Qualifications\n\nFresh Graduates\nMemiliki ketelitian dalam berkerja\nBersedia melakukan perjalanan dinas keluar kota untuk melakukan audit lapangan\nDomisili: Yogyakarta',
#  'NoLimit is a technology company focusing on Online Media Monitoring and Big Data Solution. We are inviting young and passionate professionals for our vacant position as Customer Success.\n\nWhat You’ll Do\n\nDevelops a healthy customer relationship\nEnhance customer training to gain product value\nEvaluates & analyze customers’s needs\nConvert new leads into new clients\nEncourages customers to upgrade their products\n\nYour Criteria Will Be\n\nHas a strong interest in marketing field & communication\nHas experience & interest in SAAS industry\nFamiliar with Linux will be a plus\nHas experience as customer success, customer service and or marketing specialist\nFast learner, ability to strive in a fast-paced environment\nTech-savvy\n\nIf you think you’re the one please feel free to apply via the following link : Customer Success - Online Media Technology Partner (nolimit.id)',
#  "Qualification :\n\n\n\n\nCandidate must possess at least Bachelor's Degree in Mathematics/ Information Technology/Computer Science\nAt least 5 Year(s) of working experience in the related field is required for this position. (Data Analyst)\nHaving knowledge about: Oracle, Tableau, SQC Query, Data Mining, Expert XL 8 Reporting, Power BI, Charting & Powerpoint on hand.\nRequired Skill(s): Excel, PowerPoint.\nCapability: Leadership, Persuasive, and Good Analytical.\nSoft Skill: Discipline, Hard-work, High Integrity\nPlacement: : Jakarta Pusat\n\n\n\n\n\nJob Deskription:\n\n\n\n\nMengatur urusan operational Distributor\nBTS Revenue Improvement\nmelakukan tracking, analisa dan membuat rekomendasi terkait dengan peningkatan dan pencapaian revenue BTS\nmemberikan masukan inisiatif penjualan untuk meningkatkan BTS low performance\nMengelola Database penjualan dan monitoring pencapaian\nCluster performance monitoring & analysis\nMemastikan validitas pencapaian KPI Regional di dashboard penjualan\nAdhoc repot pencapaian dan tracking\nMemastikan semua program outlet sudah di eksekusi dengan baik di tracking serta berkoordinasi dengan team CapDev terkait knowledge development untuk semua team sales\n",
#  'Qualification\n\nFinal year / fresh graduate from any major\nDetail oriented\nGood team player, positive attitude, and eagerness to learn\n\nJob Description\n\nInputing and Cleaning Data/General Ledger for accounting dept needs\nInputing and Cleaning raw data from omnichannels company sales\nUpdating database if necessary',
#  'Responsibilities:\n\nThe main responsibility of this position is to analyze sales drivers, financial and market performance and contribute to the achievement of sales and profit in a range of categories.\xa0\xa0\n\n\n\n\nRequirements:\n\nBachelor Degree or higher, from any major.\nOver two years as analyst that dealing with commercial activities, merchandising, databases/data management, reporting and analysis at retail, manufacture or distribution company/consultancy.\nExperience with category management and business analysis will be advantage due to the nature of this role.\nBroad knowledge of Indonesia retail industry especially food retailing modern market.\nUnderstand the basic principle of category management.\nAble to take detail and large data reports, validate the data and interpret them to turn them into concise, actionable insight.\nExcelling in Microsoft excel including the macro function, good knowledge in Microsoft SQL studio will be advantage, and able to adapt to using new software for interrogate databases is a must.\nWriting, proofing, editing and communicating in English.\nGood command in presentation skill.\nPlacement: JAKARTA',
#  'Requirements\n\nMin. D3/S1 in any major\nAt least 1 Year of working experience in the related field is required for this position.\nFLUENT Skill: Microsoft Excel (Pivot, IF, V/H Look Up)\nGood in administration skills, detail oriented & multitasking.\nLocation: Jakarta / Tangerang (salah satu)',
#  'Collect relevant data, perform quantitatives and qualitative analyses and detail thought into business insight and recommendation\nMonitor, analyze & provide recommendation regarding industry trends, competitive landscape, and emerging segments\nActing as PMO to integrate collaborative efforts of specific project related functions in specific area to encourage achievement of projects\nSupport Sales Head to develop, formulate, and monitor strategic plan\n\nMinimum Qualifications\n\nMinimum Bachelor Degree in any field\nPrefer having an experience in food/consumer goods\nHave a strong critical thinking, analytical and problem solving\nHave a good interpersonal skill and ability for maintaining good relationship',
#  'Company Description: SigmaTech is the enterprise technology partner of choice for software development, delivering a broad range of web, mobile, and desktop controls coupled with a service-oriented approach throughout the entire application life cycle. SigmaTech consists of highly skilled developers specializing in agile development methodology, focusing on Mobile & Web Solution, IT Services and business enterprise, utilizing modern programming languages as our platform. SigmaTech has established itself as the trusted partner for use in mission-critical applications and service clientele from global insurance company, government agencies and large consumer product manufacturer. Job Description:\n\nIdentify technical obstacles early and work closely with team to find creative solutions to build prototypes & develop deployment strategies, procedures\nProvide preventative maintenance, troubleshooting, and quick resolution of routine problems to ensure Database infrastructure and application stability\nWrite and analyze queries, object oriented and/or scripting languages\nTake an active role in Squad\nAbility to grasp new technologies rapidly as needed to progress varied initiatives - Break down data issues and resolve them\nMake sure data movement and do documentation\nImprove skills as a professional and a team',
#  "Company Description: We believe that the mind is the root of human behavior, and it is mainly influenced by education. Politics with advanced integrity starts with education, so are healthy and sustainable economic development, technology, and impactful innovation. Therefore, if we’re dreaming of establishing further civilization, we should start from an impactful, inclusive, and meaningful education. That’s us, and that's what we're believe. So if you have a strong vision about disrupting Indonesia's Education Landscape with Business and Technology, join us and challenge yourself! Job Description:\n\nMelakukan live session untuk membahas homework bersama student\nMemberikan nilai dan feedback terhadap homework student\nMendampingi konsultasi student terkait homework yang dikerjakan\nMengisi dokumen administratif terkait proses pembelajaran",
#  'Gambaran Pekerjaan\n\nSebagai Business Development Analyst, anda akan bertanggung jawab dalam melakukan riset pengembangan mall. Monitor tren customer, melakukan analisa data dan report, serta melakukan survey kepada customer dan taraf kepuasan tenant.\n\nKualifikasi\n\nPengalaman 1 tahun di bisnis analytic/ fresh graduate (S1)\nMenyukai bidang analisis data\n\nSkill yang Dibutuhkan\n\nExcel\nProgramming language; SQL, R, Phyton, Flutter\nPaham dashboard tools (tableau) dan web analytics tools (google analytics or amplitude)\nKomunikatif',
#  "Job Description\n\n\n\n\nThis role is on the Homepage Operations within Lazada’s SEA platform User Operations team. With our team, you will deliver homepage product projects to drive a significant impact on Lazada's customers. This role requires strong problem-solving and analytical skills, superb customer insight, excellent planning and the ability to articulate and present information to partners at all levels of the business.\n\n\n\n\nJobscope\n\n\n\n\nWork closely with Homepage Product Managers, to break-down homepage targets, operation strategies, and develop operating framework for initiatives related to user growth, content operation, product operation.\nLiaise with internal stakeholders across markets, to introduce frameworks, understand & integrate local business strategies; and get a clear understanding on the opportunities of each market.\nDrive feature release and lead continuous performance improvements, by translating data into actionable insights, and sharing best practice across ventures.\nResponsible for coordinating resources to promote the users growth for the homepage product, follow-up project progress, and internal and external Effective team communication to complete the user growth target.\n\n\n\n\nJob Requirements\n\n\n\n\nAt least 3 years of work experience, ideally in eCommerce or Retail industry. Have relevant experience in product operation, or content operation, category operation are highly preferred\nExcellent user experience design sense and skills, unique and keen understanding of user requirements.\nBe curious about products, have a strong sense of responsibility, good teamwork, have good communication and coordination skills, and be able to withstand pressure.",
#  'Job Description\n\nMelakukan input, merapikan data sesuai format dan updating data ke dalam format spreadsheet.\nSortir dan kelola sejumlah besar data dan file dalam sistem sesuai dengan standar\nMenghandle data order dari customer dan selalu memastikan bahwa semua sudah terupdate\n\nRequirement\n\nMahasiswa tingkat akhir atau Fresh graduate dari bebagai jurusan (lebih disukai dari jurusan statistika, matematika, administrasi bisnis, manajemen)\nBerfokus pada detail dan mampu untuk bekerja di bawa tekanan\nTerbiasa dan mampu mengoperasikan Microsoft Excel atau Google Spreadsheet\nMemiliki keterampilan mengelola data dan manajemen waktu yang baik\nJujur dan berintegritas untuk menjaga kerahasiaan data\nBersedia untuk bekerja secara WFO di Yogyakarta',
#  'Handle projects as needed in each department\nUnderstand each department’s daily processes and goals\nProvide administrative support (e.g. data entry)\nParticipate in company’s strategic planning and carry out performance evaluation (e.g. writing reports, analyzing data, create and give presentation)\n\nMinimum Qualifications\n\nMinimum Bachelor Degree from all major\nGPA : 3.00 / 4.00\nFresh Graduates or maximal 2 years work experience\nFluent in English for both verbal & written\nWilling to relocate in any place across Indonesia',
#  'detikcom is looking for a Data Analyst to join our Ads Operation team.\n\nResponsibilities\n\nManage projects by identifying issues, gathering information from various sources, analyzing data, and interpreting trends or patterns to generate insights about the market to support business decisions.\nPerform data analysis and give recommendations based on campaign performances\nManage and maintain data website performance and all data needed to support the business team.\nBuild and monitor audience data behavior to define audience segmentation.\n\nRequirements\n\nA Critical Thinker With Strong Problem-solving, Analytical Skills And The Eagerness To Learn\nDetail-oriented With The Ability To Multitask And Meet Deadlines With Minimum Supervision\nHighly Flexible, Easy To Adapt In A Fast-paced Environment, And Thrives In A Team Environment\nUnderstand Business In Online Media Publisher\nExperience With Analytics Platforms Is Preferred\nExpert In Excel/spreadsheet\nExperience With Google Analytics, Google Ad Manager, Or Competitive Analysis Tools Is A Plus',
#  'Mengkoordinasikan dan memonitor penyusnan rencana Roadmap teknologi serta implementasi arsitektur IT untuk memastikan pelaksanaan pengembangan teknologi berjalan dengan kebijakan yang berlaku dan target yang ditetapkan;\nMelaksanakan dan memonitor pengembangan layanan dan solusi IT agar pengembangan yang dilaksanakan sesuai dengan strategi dan rencana yang telah ditentukan;\nMelaksanakan koordinasi dan memonitor kegiatan perbaikan data untuk menjamin kualitas data terjaga dengan baik dan akurat\nMelaksanakan koordinasi dan memonitor penanganan terhadap incident dan problem/troubleshoot pada IT yang timbul dari kegiatan operasional\n\nKualifikasi\n\nPendidikan Min. S1 Teknik Informatika, Elektro, Sistem Informasi Manajemen, dan Matematika\nMemiliki pengalaman min. 5-7 tahun di bidang Sistem dan Development IT\nMemiliki pengetahuan yang kuat di bidang; Risk Management, IT Analysis, Design & Development, IT Architecture, Operation Management\nGood leadership and management skills',
#  'Build dashboards, self-service tools, and reports to analyze and present data associated with business operations performance to support key business stakeholders to make data-driven decision in the organization\nManaging master data, including creation, updates, and deletion.\nManaging users and user roles.\nProvide quality assurance of imported data\nProcessing confidential data and information according to guidelines.\nManaging and designing the reporting environment, including data sources, security, and metadata.\nSupporting the data warehouse in identifying and revising reporting requirements.\nSupporting initiatives for data integrity and normalization.\n\nMinimum Qualifications\n\nExcellent data analysis skills, with the ability to pull from many different data sources and provide insights on that data\nMinimum 2 years of analytics experience working with a data analyst\nMinimum 2 years of experience with BI tools like Tableau, Data Studio, Power BI, etc\nMinimum 2 years of experience in SQL, Python, R, and/or big data framework is preferred\nAbility to analyze data and build models\nPassionate in Data Analytics\nProven ability to work independently, self-motivated, self-starter who can initiate ideas and take ownership of work\nExcellent problem solving and visual thinking skills\nStrong collaboration skills\nFamiliarity with Helical Insight is a plus\nWilling to be traveling/locate in Lampung',
#  "Company Description: We believe that the mind is the root of human behavior, and it is mainly influenced by education. Politics with advanced integrity starts with education, so are healthy and sustainable economic development, technology, and impactful innovation. Therefore, if we’re dreaming of establishing further civilization, we should start from an impactful, inclusive, and meaningful education. That’s us, and that's what we're believe. So if you have a strong vision about disrupting Indonesia's Education Landscape with Business and Technology, join us and challenge yourself! Job Description:\n\nConduct research to support business needs\nCrafting question list to collect data from user\nInterpreting business goals in to objective research\nAnalyzing and synthesis data",
#  'Job Tittle- Data Entry Celrk -Remote\n\nJob location- Remote\n\nSalary Depending on Candidate Experience\n\nOpening Required 10 Data entry operator.\n\nFresher can also apply.\n\nEnter data into system accurately and efficiently Organize and maintain files and records Perform other duties as assigned by the supervisor.\n\nCompiling, verifying the accuracy, and sorting information to prepare source data for computer entry.\n\nReviewing data for deficiencies or errors, correcting any incompatibilities, and checking output.\n\nRequired Candidate profile.\n\nGOOD KNOWLEDGE OF COMPUTER MUST HAVE LAPTOP OR SYSTEM MUST HAVE BASIC TYPING SPEED MUST HAVE TYPING ACCURACY NO WORK PRESSURE & NO TIME BOUNDATION',
#  "Responsibilities\n\nInput data of operational transactions in to the systems\nPerforming appropriate controls and documentations\nAssisting others in the Finance Team with any other duties as required\n\nRequirements\n\nBachelor's Degree from accounting / Economic\nMinimum 1-2 years experience\nWorking knowledge of database and spreadsheet software, such as Excel\nShould be analytical, independent, and able to take initiative\nStrong in number and analytical thinking\nPlacement : Jakarta Pusat",
#  'Data stream cleaning.\nData stream analysis\nWrite a short report related to the results of the reporting study data\nData visualization\nReporting - Data Analysis Results\n\nMinimum Qualifications\n\nBachelor degree of statistics or mathematic would be better / Minimum of 5th semester active students and not participating in KKN or Internship programs.\nDomiciled in the DKI Jakarta area or willing to hybrid from Tebet (2-3 days in a week)\nHave the capacity in the field of data processing using excel or other statistical software.\nHave an interest in writing studies or articles',
#  "Job Description\n\n\n\n\nAnalyze data to bring insights that can help solve problem or prevent future problem to arise -\nCreate hypothesis and test hypothesis using our data. If we don't have the data, propose a way to capture and extract the needed data to stakeholders.\nTrain data model based on our current data\nDefine and monitor key metrics and alert the business on potential issues.\nAnalyze operational efficiency and build business models to guide decision-making.\nDesign market/business intelligence reports and performance measurement dashboards.\nEnhance our data infra, analyze large, complex data sets into actionable insights.\n\n\n\n\nQualifications\n\n\n\n\nAt least a Bachelor degree in computing intensive subjects, e.g. financial mathematics, computer science, mathematics, physics, bio-informatics, engineering\nKnowledgeable in SQL, data visualization using tools like Tableau and can code basic Python/R\nAdvanced statistics knowledge\nUnafraid to deal with large, dirty, and messy data and can create ETL to clean and make the data workable - Amazing problem solver\nExperienced in using advanced analytics/machine learning in the real world scenario\nPast participation in science Olympiad or Kaggle is a plus",
#  "Update monthly exchange rates Reconciliation Intercompany.\nClosing Universal's FS.\nUpdate Real Shipment, Cost Of Production, Insurance, COP, monthly exp.\nUpdate Console report (actual and forecast).\nUpdate monthly achievement monitoring.\nUpdate GGP Cashflow.\nTB Mapping report to GSK (quarterly).\nReview New Contract.\nDeclaration sales transaction to Insurance company.\nMonitoring outstanding insurance claims and other administrations.\n\nMinimum Qualifications\n\nMinimum 2 years experience in accounting or the same job role.\nHave good analytical thinking and data analyst.\nNegotiation skills and the ability to develop strong working relationships\nCommercial and business awareness\nGood communication skills – both written and verbal\nKeep eye for detail and desire to probe further into data.\nDeadline-oriented and an ability to stick to time constraints.",
#  'Broad cross functional duties within the Process Governance Unit, serving the Process Architecture and Group Policy and Risk functions.\n\nThe job role has diverse responsibilities and requires the analyst to be highly adaptable, possess a keen learning attitude and ability to prioritize and manage tasks from various functions. The role is designed to also serve as a development platform for future Process Architects and Group Policy and Risk specialists.\n\n\n\n\nPast experience in SAP Finance and Controlling is preferred - ideally possesses good understanding of the core functionalities and resulting accounting entries, and good appreciation of integration to Procurement, Sales, Logistics.\n\n\n\n\nJob Description:\n\n\n\n\nProcess Architecture\n\n1. Support role to Process Architects as Process Analysts including but not limited to development and maintenance of process hierarchies, process flows, competency frameworks\n\n2. Maintains process management standards and performs compliance checks against standards.\n\n3. Works with Business Units to identify process issues, performs root cause analysis, assess and recommend solution options.\n\n4. Manages improvement initiatives from initiation thru realization of benefits - business case framing, planning, progress monitoring, managing stakeholders and facilitate escalations when necessary.\n\n5. Review of CRs (Change Requests) to ensure business changes are qualified, impacts are adequately assessed, compliance to internal, external regulations and statutory reporting.\n\n\n\n\nGroup Policy and Risk Management\n\n1. Review of escalated Segregation of Duties (SOD) risks and working with respective business units to define and implement mitigating controls.\n\n2. Assist in the maintenance of Group-monitored risks, and assist in preparation and execution of the Risk Management Programme within the group.\n\n3. Group Policies - assist in the research, consultation with SME functions, data collection, policy writing, facilitation of reviews and approvals.\n\n\n\n\nJob Requirements:\n\nAt least 3 year of working experience.\nFast learner\n\n\n\n\n“Our company has never levied any fees for recruitment process nor has it required to order tickets and accommodation through a certain travel agent or certain person”',
#  'Monitoring both business and consumer transactions\nEnsuring the agreed SLA is met\nOnboarding merchants to the proposed and selected products\nCoordinating with every stakeholder for transactional update\nCommunicating with every partner for maintenance and disturbance\nHandling every transactional issue\n\nMinimum Qualifications\n\nPrevious Working experience in related field 1 - 3 years.\nFresh graduates are open to applying.\nProficient at using Microsoft Office Tools (Word, Powerpoint, and Excel) and G-Suites (Docs, Sheets, and Docs)\nHas the ability to analyze large quantities of data, accurately diagnose root cause problems, and lead operational changes to drive business results\nGreat team player and adaptable to changes\nFamiliar with using CRM and data visualization software\nExperienced in multi-tasking with great attention to detail\nExcel work cross-functionally and are comfortable managing various workstreams simultaneously',
#  'Job Description\n\nMenyiapkan portal dashboard operational yang dapat digunakan untuk mengidentifikasi data untuk membantu management dalam membuat keputusan-keputusan strategis\nMengelola historical information yang dapat digunakan untuk review layanan operasional\nMemberikan analisa dan informasi dokumentasi terkait dengan kebutuhan penggunaan data yang dapat disampaikan baik internal maupun mitra terkait\nMemberikan masukan kepada atasan terhadap pengolahan data, analisis tren data, dari angka - angka serta kesimpulan berdasarkan dari hasil temuan data.\nMengembangkan dan menerapkan analisis data, sistem pengumpulan data dan strategi lain yang mengoptimalkan efisiensi dan kualitas statistic\nMengidentifikasi, menganalisa, dan menafsirkan tren atau pola dalam kumpulan data\n\nJob Requirements\n\nMahasiswa Akhir atau Sarjana S1 lulusan Matematika, Ilmu Komputer, Statistik, dan Ekonomi atau jurusan lain yang relevan\nFamiliar dengan Macro Excel dan VBA\nBisa mengoperasikan setidaknya satu aplikasi analisis Phyton, R, atau Java\nKemampuan untuk menulis laporan yang komprehensif\nKeahlian komunikasi lisan dan menulis yang baik, berpikir secara analitis, perhatian terhadap detail',
#  "Company Description: SigmaTech is the enterprise technology partner of choice for software development, delivering a broad range of web, mobile, and desktop controls coupled with a service-oriented approach throughout the entire application life cycle. SigmaTech consists of highly skilled developers specializing in agile development methodology, focusing on Mobile & Web Solution, IT Services and business enterprise, utilizing modern programming languages as our platform. SigmaTech has established itself as the trusted partner for use in mission-critical applications and service clientele from global insurance company, government agencies and large consumer product manufacturer. Job Description:\n\nCollaborating with other department leaders to define, prioritize, and develop projects.\nPlanning project management, including setting deadlines, prioritizing tasks, and assigning team members to various deliverables.\nAnalyzing financial data, including project budgets, risks, and resource allocation.\nProviding progress update to Executives.\nOverseeing the development of the project and ensuring that team members are carrying out their tasks efficiently while upholding the companys standards.\nDrafting new and improving existing project management office policies and processes.\nContinuously evaluating projects to ensure they are meeting company standards, adhering to budgets, and meeting deadlines.\nAccurately documenting the project's creation, development, and execution as well as documenting the projects scope.",
#  "The Business Development and Partnerships teams at Shopee are dynamic and energetic. The teams are always looking to acquire business opportunities to drive Shopee to be the No. 1 e-commerce platform in Southeast Asia and Taiwan. The aim of the Business Development and Partnership teams is to provide Shopee’s buyers with a wide variety of product listings at the best prices.\n\n\n\n\nJob Description\n\n\n\n\nHandle E2E execution of Social-related campaigns such as Shopee Live Campaigns and Shopee Video Campaigns\nEnsure daily tasks are running in accordance with the project timeline to identify potential risks and escalate issues to upper management when needed\nAct as a center of communication between all Campaign stakeholders (Marketing, BD Category, etc)\nCraft seller campaign programs in a way that is able to help Shopee grows and at the same time addressing seller's needs\nKeep on track with what's happening on the market (competitive intelligence, competitor benchmarking, etc)\n\n\n\n\nRequirements\n\n\n\n\nBachelor’s degree from all majors with 0 to 1 year of working experiences are welcomed\nHave experience in Project Management and Data Analytics will be a plus\nStrong attention to detail with the ability to quickly adapt to new changes\nAbility to process and evaluate data-driven reports to strategise an effective plan\nWilling to work for 3 months contract based",
#  '1. Experiences as Business System Analyst / Business Analyst for >= 5 Years\n\n2. Have good analytical, problem solver / able to have tshoot capability during Business Case / Project initiation / Production Support after Project Go live\n\n3. Hands on with SQL Data Manipulation Language (DML); Data Definition Language (DDL); Structure of an SQL Command (execute / Read).\n\n4. Have experience with end to end application in Insurance or Banking.\n\n5. Have deep Knowledge with Insurance Business Process and integration with multiple process flows / Systems ; added value if understand Financial and point of sales area.\n\n6. Have knowledge and experience in Core System enhancement or projects i.e Life Asia/AS400, system table setup, compensation system, lettering system, SMS & Email sending system, etc.\n\n7. Have knowledge and experience in using SSIS.\n\n8. Have deep explore requirements or business needs and challenge the needs in order to get an effective and efficient process\n\n9. Familiar with Agile Development Lifecycle / Waterfall Development Lifecycle Processes: reflecting on previous projects cycles and involvement\n\nRequirement Gathering Process, Analysis and Design, Support Testing/Testing, review testcase, Production Support.\nDeliverables/Output: produce and review Business Requirements Document (BRD) / Function Technical Document (FTD)\nDaily stand-up meeting, sprint planning, backlog grooming, sprint retrospective, and all activities that related to Agile way of works.\nPerform data mapping for integration requirement.\n\n10. Communication and Leadership\n\nProactive and target driven and yet communicative with manner to the teams\nDaily update to appointed PIC\n\n11. Have good team management, monitor, and support the team to achieve the same goal in project / task\n\n12. Can work and manage more than one activity with proper timeline, output, and documented\n\n13. Able and fluent in English speaking and writing.\n\n14. "Familiar with JIRA software development projects and confluence"\n\n15. Collaborating with prospective users and clients to understand and anticipate their needs and translate them into product requirements\n\n16. Managing the product backlog based on changing requirements\n\n17. Developing user stories\n\n18. Liaising with the team member and product owner to deliver updates\n\n19. Participating in Scrum meetings and product sprints',
#  "Who We Are\n\n\n\n\nOrange provides your personalized go-to pool of strategy planners, creatives, and technologists for your brand and campaign that aren't part of your daily routine. Strategic managers, content specialists, conceptual creatives, producers, SEO experts, product managers, and others are among the impact players who are held match-fit for your brand.\n\n\n\n\nWhat You Will Do:\n\n\n\n\nPropose cascading of data attributes that are impactful for the identification of unified user.\nIdentify usable data for newly acquired data from Partners. Present to stakeholders with impactful insight from available data\nDetermine potential data enrichment based on existing data from established data aggregators and publicly available data\nSupport Data Engineer and Data Warehouse Engineer in translating business requirements for technical actions in the development of data platform with privacy-conscious that support ecosystem collaboration\nConduct Pilot and Testing of MVP product based on criteria of successful product\n\n\n\n\nWhat You Will Need:\n\n\n\n\nGPA > 3.2 from reputable universities\nExcellent analytical and problem solving skills\nPassion in internet products and fintech area\nProblem solver with clear structure and analytical skills.\nStrong communication skill, both verbally and in writing.\n\n\n\n\nPowered by JazzHR\n\n\n\n\nBlIgPuEbAy",
#  None,
#  "About Us\n\n\n\n\nPopulix is a consumer insights platform that helps businesses connect with its database of respondents and provides them with insights to better understand the preferences of Indonesian consumers. Populix has a pool of over 300,000 diverse, readily accessible, and highly-qualified respondents across Indonesia. Its products range from intensive research studies to simple surveys and can be arranged on a project or subscription basis. Focusing on the fact that Indonesian consumers are super sticky to their phones, Populix facilitates a diverse range of data collection methods via its mobile app.\n\n\n\n\nDon't see the perfect job for you? Drop your resume and we will reach out to you if we find the perfect fit!\n\n\n\n\nSome general requirements:\n\n\n\n\nStrong interest in the market research industry\nGood in Microsoft Office (Word, Excel, and PowerPoint).\nIndependent, good communication skills.\nProblem solver, approachable.\nData-driven, good analytical thinking.\nPreferably able to communicate in the English language.\n\n\n\n\nPowered by JazzHR\n\n\n\n\njd5A8lkieq",
#  'Job Descriptions\n\nSupporting sales in preparing quotations and tender requirement from clients\nSupporting sales with collecting client legal documents & closing business document for onboarding\nResponsible for sales activity data report\nMaintaining administrative documents and data for business\nResponsible for dealing with a wide range of correspondences – working on own initiative to take action as appropriate and referring issues to the Sales and KAM Team Leader where necessary\nArrange meetings, book facilities/equipment, prepare agendas, attend meetings, produce and distribute minutes within agreed timescales\nDiary management as required\nProvide a high quality administrative support service as required\nResponsible for maintaining filing systems for all areas of the team (Sales & KAM)\nUndertake housekeeping of electronic data systems ensuring clean live data is retained at all times\n\nRequirements\n\nAble to join immediately\nHave decent proficiency in English communication skill\nMin. 1-2 year experience as Administrative Executive, Administrative Support, Sales Support, and/or Business Support. Experience in Health Insurance companies will be a plus\nMin. Diploma Degree (III) as latest education background\nExcellent written, listening and oral communication skills;\nFamiliar and/or active with English as language\nAdvanced in excel or other equivalent numeric analysis tools\nFamiliar with CRM dashboard tools and Datastudio\nHave a knowledge in health tech/insurance/TPA would be an advantage\nDetail-oriented, and excellent with administrative task\nAgile and quick learner',
#  'About The Role\n\nAs a data analyst in the marketing team of Bank Jago, you will be a critical part of the growth of the company supporting customer acquisition and engagement. The role would require you to work closely with the marketing team, data engineers and data scientists in order to ensure the validity of the data, transforming the data to insights, and operationalizing it. Additionally, The Marketing Analyst will enable the execution of marketing campaigns. This includes responsibility for marketing campaign analytics execution (from audience identification, campaign execution, and performance).\n\nTo be successful in this position, the analyst will need prior experience in marketing analytics along with a data driven mind-set with strong communication skills to work across technical and non-technical audiences.\n\nWhat you will do day to day:\n\nUnderstand the business problem and challenges/opportunities for the business.\nInfluence the marketing team through data analysis to help support the customer acquisition and engagement goals. Examples of this would be:\nAnalyse the effectiveness of campaigns.\nCustomer profiling and segmentation.\nCohort, funnel, churn, and retention analysis.\nLogic creation and automation to be used in marketing campaigns.\nCreate dashboards for monitoring purposes.\nDevelop ETL Pipeline for analytics purposes.\nAd-hoc analysis to help address business challenges and opportunities.\nPro-active data analysis to identify problematic areas for optimisation or further investigation via customer listening.\n\n\nWhat you will need to have:\n\nA tertiary education in a quantitative discipline.\nAt least 3-years of experience in fast-paced environments.\nKnowledge of SQL, python, airflow, and BI Tools (such as Tableau, PowerBI, etc).\nAbility to translate abstract questions to tangible solutions.\nGood communication skills. Ability to work in a cross-functional team (matrix) with technical and non-technical people.\nPro-active and the ability to manage stakeholder expectations and priority.',
#  'Handle projects as needed in each department\nUnderstand each department’s daily processes and goals\nProvide administrative support (e.g. data entry)\nParticipate in company’s strategic planning and carry out performance evaluation (e.g. writing reports, analyzing data, create and give presentation)\n\nMinimum Qualifications\n\nMinimum Bachelor Degree from Information System/Technology, Business, Management, Finance & Accounting, Post-harvest Technology, Food Technology, Industrial Engineering, Agriculture (Agronomy, Plant Protection, Agriculture Engineering), Geodetic Engineering, Mechanical Engineering\nGPA : 3.00 / 4.00\nFresh Graduates or maximal 2 years work experience\nFluent in English for both verbal & written\nWilling to relocate in any place across Indonesia',
#  'Supporting Data Team (manage & maintain database)\nLooking for Data Engineering/Science (Specialize in Visualization)\nExcellent communication and presentation skills\nHave an Experience in Tableau and mySQL',
# ...
#  "Gain a deep understanding of user experience, identify and fill product gaps and generate new ideas\nWorking closely with designers, engineers and various stakeholders to coordinate, plan, execute and track product release from the beginning to the end\nDetermines user's needs and desires by specifying the research needed to obtain market information\nManage the roadmap, prioritize product opportunities, refine feature ideas and maintain existing features to drive business goals\nEngage stakeholders in leadership, research, data, support and coordinate across teams to maintain product and strategy alignment\n\nMinimum Qualifications\n\nBachelor's degree in Computer Science, Information System, Information Technology, Industrial Engineering or Business Majors\nStrong project management skills with the ability to meet deadlines, prioritize and work on multiple projects simultaneously with great efficiency and attention to detail\nUnderstanding of canvas model: idea validation, design thinking, business model\nExcellent communication and leadership skills\nA desire to work in a fast-paced results-driven environment with multiple responsibilities\nCollaborative and team worker\nStrong data-driven problem-solving skills but not afraid to use gut feeling High level of willingness to learn\nUnderstanding of JIRA and knowledge in Software Engineering, Algorithm or User Research would be a plus.",
#  'Company Description: PAN ERA GROUP merupakan induk perusahaan (Holding Company) sejak tahun 2011, untuk menaungi beberapa perusahaan diantaranya PT Elastis Reka Aktif (ERA), PT Elite Recycling Indonesia (ERI), dan PT Eterna Persada Indonesia. Lini bisnis yang dijalankan saat ini yaitu produksi bijih plastik daur ulang (recycled plastic granule) dan manufaktur kantong plastik. Setiap proses mulai dari bijih plastik melalui tahapan verifikasi oleh Quality Control (QC) hingga hasil akhir. PAN ERA GROUP berkomitmen untuk selalu mengeksplorasi dan mengembangkan inovasi baru dalam memastikan standar kualitas. Hal ini tercapai dengan SDM yang berkualitas dan komitmen untuk selalu menyediakan produk terbaik. Dalam hal pengembangan sumber daya manusia, PAN ERA GROUP secara rutin melakukan pelatihan untuk karyawannya agar setiap karyawan dapat meningkatkan pelayanan, mampu menangani masalah, dan menjaga konsistensi kualitas. PAN ERA GROUP berkontribusi terhadap kelestarian lingkungan hidup dengan melakukan aktivitas daur ulang plastik yang merupakan salah satu solusi utama dalam menjaga keberlanjutan lingkungan hidup (sustainable development). PAN ERA GROUP menghasilkan produk terbaik dengan terus mengikuti perkembangan teknologi, baik dari mesin produksi maupun teknologi informasi. Kualitas merupakan nilai yang sangat penting dalam perusahaan PAN ERA GROUP. Penerapan standar kualitas difokuskan pada pemenuhan ekspektasi pelanggan setiap saat. Job Description:\n\nMenyusun laporan keuangan dan pajak perusahaan secara berkala, serta transaksi finansial perusahaan. Terbuka penempatan untuk di daerah Kapuk - Jakarta Utara\n\nTugas & Tangung Jawab\n\nMengelola seluruh administrasi dan support efektif\nMelakukan penagihan terhadap customer yang jatuh tempo efektif\nMembuat pembukuan bank perusahaan efektif\nMengontrol penagihan dan pembayaran efektif\nMembuat jurnal sampai dengan laporan keuangan dan filling semua data pendukung efektif\nMembuat laporan laba rugi efektif',
#  "The ideal candidate will use their passion for big data and analytics to provide insights to the business covering a range of topics. They will be responsible for conducting both recurring and ad hoc analysis for business users.\xa0\n\n\xa0\n\nResponsibilities:\n\nAnswer business questions from product and marketing using available big data such as financial transactions, web/mobile product interactions, and advertisement responses\nWork with product managers and marketing to understand their analytical needs and communicate results clearly, both verbally and in writing\nTake initiative to create new insights that will improve product and marketing projects\nKnowledge of product/marketing metrics and attribution models\nAccess, transform, visualize, and model datasets with minimal engineering support\nPre-process data: data cleaning and deriving new features\nVisualize data using tools like Excel, Tableau, Google Data Studio, or MongoDB Charts\n\n\n\n\nQualifications:\n\nMinimum 2 years of work experience in Data Science or related field\nBachelor's or Master's degree in Computer Science (Artificial Intelligence / Machine Learning), Statistics, or Mathematics\nStrong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and accuracy\nWorking knowledge of machine learning (regression, classification, clustering)\nWorking knowledge of Python and SQL (MongoDB is a plus)",
#  'S1 In computer Science , Information Technology , or related field\n\nMinimun in 1-2 years experience in database engineer\n\nAcchievment orientation (Level 2)\n\nInformation seeking (Level 2)\n\nBusiness Process Understanding\n\nMaster Data Manangement\n\nFlexibility (Level 2)\n\nExcellent PDCA (Level 2)\n\nETL concept & tools\n\nOLAP concept & tools\n\nInterpersonal Understanding (2)\n\nTeamwork & Collaboration (Level 3)\n\nMs. SQL , Ms. Query Tools\n\nDAX Syntax',
#  'Company Description: Skolla adalah platform belajar canggih yang bakalan jadi sekolah masa depanmu, dengan mengolaborasikan edukator profesional dan teknologi terkini. Skolla menumbuhkan potensi terbaik setiap individu dengan menghadirkan pengalaman belajar yang menyenangkan sesuai dengan keunikan siswa. Job Description:\n\nMembuat laporan keuangan\nFollow up invoice & payment\nBertanggung jawab atas petty cash harian\nMemasukkan data jurnal akuntansi ke dalam sistem perusahaan\nMemeriksa dan memverifikasi kelengkapan dokumen terkait transaksi keuangan',
#  None,
#  "Experience 1-7 years\nMin. Bachelor's degree (S1) in IT\nSkills & knowledge : SQL, Excel, Data mapping & modeler, R/phyton, Power BI, OLAP Model, Accounting standard\nExperience working in insurance / financial /digital business",
#  'Arkademi is Indonesia #1Certified Online Course App. We are Helping 130 million of Indonesian’s workers to upskill and get professional certification at scale. Learning system at Arkademi is devoted to skill-based learning delivered through learning classes and online courses through the mobile app and web-based Arkademi application. At Arkademi every individual and course institution can open and commercialize their online classes and reach students from all over Indonesia. Awarded as #2 Top Adult Learning Apps by Daily Social and 50 SEA Next Big Thing Ed-Tech Start Up by Tech in Asia.\n\nWhat You Will Do\n\nPerform data analysis for developing data\nPerform data withdrawals according to the request\nCreate report templates\nMigrating data to big query\nDoing model business data reports\nUpdate All Data (real time or not) and request data from other divisions\nDeliver data to stakeholders\nDo tracking data\nCalculating data Journey (to be included in the project review)\n\nRequirements\n\nMinimum Bachelor degree in Information Technology or having proven experience as data developer at least 6 months\nExcellent data collection & analytical skills\nExcellent logical thinking\nHighly proficient in using Ms. Office and Google Spreadsheet formula\nGood knowledge of data migration, query formula, data studio, system report, computational modelling, and Google Analytic',
#  'Job Description\n\nOwn the full spectrum of business and operation goal of the organization\nTranslate strategy into actionable goals for performance and growth\nCollaborate with the Department Head, in setting and driving the organization goal and strategy\nImplement organization-wide goal setting, performance management, and periodically (annually and quarterly) operating planning\nOversee organization’s operations and employee productivity, building a highly inclusive culture ensuring team members thrive and organizational outcomes are met\nDevelop and implement policies and procedures to ensure that core operational functions achieve their business objectives\nDevelop and control operational budgets to promote profitability and ensure the company has all the resources required to meet its objectives within agreed financial parameters\nDevelop actionable business strategies and plans that ensure alignment with short-term and long-term objectives developed in tandem with the Department Head\nDirect, oversee and lead three cross functional teams : the operations team, the business executive team, and the commercial team, to ensure execution of the overall organization strategy\nEvaluate overall organization performance by gathering, analyzing and interpreting data and metrics\nAct as the organization’s main adviser on all issues relating to operational functions and keep abreast of latest developments to ensure that the organization maintains its competitive position\n\nRequirements\n\nAt least 8 years experience in b2b E-commerce or supply chain industry, working on business or operations leadership position, preferably at the senior managerial level and from multinational company\nStrong analytical thinking and problem solving skills using various improvement tools and methods\nSolid leadership skills, with steadfast resolve and personal integrity\nUnderstanding of advanced business planning and pharmaceutical distribution regulatory issues\nGood understanding of supply and demand planning\nGood attention to detail and routine activities\nAble to generate creative solutions towards operation issues and empower relevant teams to execute the solutions properly\nAble to handle communications within the community and in a mass conflict situation\nProficient in English (verbal and written)\nHaving a pharmaceutical distribution background would be a plus',
#  "Hey problem solver! Are you ready to join the revolution? Indepay | Setara Networks is looking for an Associate Product Manager to help us change the game in the Indonesian payment ecosystem.\n\nWe're on a mission to make digital transactions fast, fee-free, and secure. We're working with merchants and banks to enable real-time bank transfers and giving consumers a payment product that's blazingly fast, reliable, and better than anything else on the market.\n\nAs our Associate Product Manager, you'll partner with our design, business, and engineering leaders to launch next-generation payment products that are exceptional in quality and delivered on schedule. We need someone who's obsessed with solving for user needs, can put themselves in customers' shoes, and has an extreme attention to detail when it comes to thinking of solutions.\n\nWe believe this is a rare opportunity to be one of the very first people in our company. So, what are you waiting for? If you've spent 3+ years managing tech products and are ready to dive deep, come join our team and help us shape the future of payments in Indonesia.\n\nApply now and let's make history together!\n\nResponsibilities\n\nDevelop and maintain a prioritized product roadmap for the next 12-24 months with well-defined product requirements and business justifications\nMaintain knowledge of the technical and operational elements of your product which should inform decision making\nDeeply understand for whom you are building and why\nMaintain regular contact with users to ensure product decisions are informed with a user-first mindset\nDevelop clear product requirements and communicate them with engineering teams and designers\nIterate and test product design concepts rapidly to arrive at the best solutions\nBe the glue in a diverse cross-functional environment and help drive decisions and consensus\nUse metrics to inform your point of view and leverage analytics to measure success\n\n\nRequirements\n\n3+ years of demonstrated experience in Product Management (payments experience is a major plus)\nExperience owning end-to-end product development, through concept, to launch and growth\nUnderstanding of market and customer research, designing the product architecture, UI development, and payment domain knowledge in a start-up company\nMust be comfortable working in an early stage to growth stage company and should be able to thrive in a dynamic and fast-paced environment\nHave a proven track record of success in previous roles and have worked in a similar setting, such as a Pre-series A-B company will be a plus\nA leader who takes fun in taking risks and understands that taking calculated risks is necessary for growth\nExcellent communication skills – verbal and written\nPassionate about building great products and solving customer and business problems\nUnderstanding of technology, but love customer-first and business-first thinking\n\n\nSkills\n\nAnalytical and data-driven approach in day-to-day work\nAbility to work well under pressure and deliver on commitments\nExcellent problem-solving and analytical skills, and can think outside the box to proactively provide the right solution\nGood communication skills and the ability to impact and influence\nStrategic thinker who understands business opportunities to create a competitive advantage\nKeen eye for detail and ability to multi-task with excellent time management and prioritization skills\nPositive attitude and determination to succeed against all odds\nHands-on, independent, self-motivated, and a fast learner\nPatience and perseverance are key attributes\n\n\nBenefits\n\nCompetitive salaries and generous benefits\nOpportunity to work alongside passionate and talented individuals\nEntrepreneurship culture with a focus on creating a budding ground for future entrepreneurs\nPerks and flexibility of a technology product company\n\n\nIf you are excited about building a new payment network, Open Banking, Big Data, Data Science, Automatio ...
#  'Human Resources Intern - AlloFresh (3-months period)\n\n\n\n\nAlloFresh is a joint venture company between Bukalapak, Trans Retail Indonesia, and Growtheum Capital Partners. Established in early 2022, we offer more than 150,000 SKUs that can be delivered in three hours to your doorstep.\n\n\n\n\nWe’re expanding the business to more cities across Indonesia & welcoming a great talent like you. Let’s enjoy the ride together!\n\n\n\n\nResponsibilities:\n\nRecruitment: screen resumes and application forms, schedule and confirm interviews with candidates, and manage the career site\nEmployer Branding: creating several employer branding initiatives and manage the LinkedIn page\nL&D and OD: assisting and supporting the learning & development and organizational development initiatives\nAnd many more exciting HR ad-hoc projects\n\n\n\n\nRequirements:\n\nFinal year students or fresh graduates, preferably from business, human resources, engineering and/or other related background\nComing from reputable university in Indonesia and/or overseas\nProficiency in data visualization tools is a must\nUsed to operate Google Workspace (Google Spreadsheet, Google Docs, Google Slides, etc.)\nStrong English proficiency (verbal and written)\nStrong analytical skills with structured thinking\nHighly initiative, proactive, and collaborative\nReady to become a collaborative team player in a dynamic yet fun working environment']

# %%
job_data = pd.DataFrame({
    'Date': date_list,
    'Company': company_name_list,
    'Title': job_title_list,
    'Location': location_list,
    'Description': jd,
    'Level': seniority,
    'Type': emp_type,
    'Function': job_func,
    'Industry': job_ind,
    'Link': job_link_list
})

# %%
job_data.to_csv("data/LinkedinScrape_{0}_{1}_.csv".format(job_name,country_name), sep=';', index=None)

# %%
job_data.sample(5)
# Out:
#            Date                           Company  \
# 66   2023-04-10                  Kawan Lama Group
# 42   2023-04-06                GTech Digital Asia
# 113  2023-03-31                           Reckitt
# 138  2023-02-24  PT Astra Digital Arta (AstraPay)
# 134  2023-02-27            PT Bank Mandiri Taspen
#
#                              Title                          Location  \
# 66                   Data Engineer  West Jakarta, Jakarta, Indonesia
# 42          Data Intern in MAPCLUB         Jakarta Metropolitan Area
# 113  Performance Marketing Analyst       Jakarta, Jakarta, Indonesia
# 138        Product Ownership Staff       Jakarta, Jakarta, Indonesia
# 134                     Internship       Jakarta, Jakarta, Indonesia
#
#                                            Description             Level  \
# 66   Gambaran Pekerjaan\n\nSebagai Data Analyst, An...       Entry level
# 42   Supporting Data Team (manage & maintain databa...        Internship
# 113  Description\n\n\n\n\nWant to find a smarter wa...  Mid-Senior level
# 138  Gain a deep understanding of user experience, ...  Mid-Senior level
# 134  Melakukan analisis dan riset data (data analyt...        Internship
#
#            Type                        Function  \
# 66    Full-time          Information Technology
# 42   Internship          Information Technology
# 113   Full-time                           Sales
# 138   Full-time  Sales and Business Development
# 134   Full-time          Education and Training
#
#                           Industry  \
# 66                          Retail
# 42   IT Services and IT Consulting
# 113          Consumer Goods Rental
# 138             Financial Services
# 134             Financial Services
#
#                                                   Link
# 66   https://id.linkedin.com/jobs/view/data-enginee...
# 42   https://id.linkedin.com/jobs/view/data-intern-...
# 113  https://id.linkedin.com/jobs/view/performance-...
# 138  https://id.linkedin.com/jobs/view/product-owne...
# 134  https://id.linkedin.com/jobs/view/internship-a...

# %%
job_data.shape
# Out:
# (149, 10)

# %%
job_data[job_data.Industry.notna()]
# Out:
#            Date                               Company  \
# 0    2023-04-11         PT Adaro Energy Indonesia Tbk
# 1    2023-02-13                     NoLimit Indonesia
# 2    2023-04-10                             Bukalapak
# 3    2023-03-17  PT. Sigma Cipta Caraka (Telkomsigma)
# 4    2023-01-16             PT Onix Kreatif Indonesia
# ..          ...                                   ...
# 144  2023-02-13          PT Macra Teknologi Indonesia
# 145  2023-04-04                              Arkademi
# 146  2023-03-06                               Halodoc
# 147  2023-03-29             Indepay | Setara Networks
# 148  2023-04-11                             Bukalapak
#
#                                                  Title  \
# 0                                                    1
# 1                                  Junior Data Analyst
# 2                       Business Intelligence (iPrice)
# 3    Data Architecture and Modelling (Multifinance ...
# 4                                           Accounting
# ..                                                 ...
# 144                                       Data Analyst
# 145                                     Data Developer
# 146                        Head of Business Operations
# 147                          Associate Product Manager
# 148                 Human Resources Intern - AlloFresh
#
#                           Location  \
# 0    Lembang, West Java, Indonesia
# 1    Bandung, East Java, Indonesia
# 2               Jakarta, Indonesia
# 3      Jakarta, Jakarta, Indonesia
# 4        Jakarta Metropolitan Area
# ..                             ...
# 144      Jakarta Metropolitan Area
# 145      Jakarta Metropolitan Area
# 146      Jakarta Metropolitan Area
# 147      Jakarta Metropolitan Area
# 148      Jakarta Metropolitan Area
#
#                                            Description             Level  \
# 0    Job Responsibilities\nTo analyze the impact of...    Not Applicable
# 1    What You’ll Do\n\nAnalyzing Data\nReporting da...    Not Applicable
# 2    A part of Bukalapak, iPrice is the place price...  Mid-Senior level
# 3    Company Description: SigmaTech is the enterpri...       Entry level
# 4    Requirements\n\nMin SMK Akuntansi/D3/S1 Jurusa...         Associate
# ..                                                 ...               ...
# 144  Experience 1-7 years\nMin. Bachelor's degree (...          Director
# 145  Arkademi is Indonesia #1Certified Online Cours...       Entry level
# 146  Job Description\n\nOwn the full spectrum of bu...          Director
# 147  Hey problem solver! Are you ready to join the ...  Mid-Senior level
# 148  Human Resources Intern - AlloFresh (3-months p...        Internship
#
#            Type                                           Function  \
# 0     Full-time                                              Other
# 1     Full-time                             Information Technology
# 2     Full-time  Information Technology, Other, and General Bus...
# 3     Full-time                             Information Technology
# 4     Full-time                    Accounting/Auditing and Finance
# ..          ...                                                ...
# 144   Full-time             Information Technology and Engineering
# 145   Full-time                             Information Technology
# 146   Full-time                       Management and Manufacturing
# 147   Full-time                                 Product Management
# 148  Internship                                    Human Resources
#
#                                               Industry  \
# 0                                               Mining
# 1                         Online Audio and Video Media
# 2    IT Services and IT Consulting, Information Ser...
# 3                        IT Services and IT Consulting
# 4                                               Retail
# ..                                                 ...
# 144                               Software Development
# 145                      IT Services and IT Consulting
# 146               Technology, Information and Internet
# 147               Technology, Information and Internet
# 148                      IT Services and IT Consulting
#
#                                                   Link
# 0    https://id.linkedin.com/jobs/view/1-at-pt-adar...
# 1    https://id.linkedin.com/jobs/view/junior-data-...
# 2    https://id.linkedin.com/jobs/view/business-int...
# 3    https://id.linkedin.com/jobs/view/data-archite...
# 4    https://id.linkedin.com/jobs/view/accounting-a...
# ..                                                 ...
# 144  https://id.linkedin.com/jobs/view/data-analyst...
# 145  https://id.linkedin.com/jobs/view/data-develop...
# 146  https://id.linkedin.com/jobs/view/head-of-busi...
# 147  https://id.linkedin.com/jobs/view/associate-pr...
# 148  https://id.linkedin.com/jobs/view/human-resour...
#
# [146 rows x 10 columns]
